# %%
import json
import pickle

# %%
# downloaded from https://hay.toolforge.org/propbrowse/
# https://www.wikidata.org/wiki/Wikidata:List_of_properties
with open('props.json', 'r') as fd:
    props = json.load(fd)

# %%
len(props)
# Out:
# 12286

# %%
non_id_props = [p for p in props if 'ID' not in p['label']]

# %%
len(non_id_props)
# Out:
# 3960

# %%
#non_id_props[:10]

# %%
datatypes = set([p['datatype'] for p in props])

# %%
datatypes
# Out:
# {'commonsMedia',
#  'entity-schema',
#  'external-id',
#  'geo-shape',
#  'globe-coordinate',
#  'math',
#  'monolingualtext',
#  'musical-notation',
#  'quantity',
#  'string',
#  'tabular-data',
#  'time',
#  'url',
#  'wikibase-form',
#  'wikibase-item',
#  'wikibase-lexeme',
#  'wikibase-property',
#  'wikibase-sense'}

# %%
datatypes_to_keep = set([
    #'commonsMedia',
    #'entity-schema', # could be useful for future works in entity linking or slot filling
    #'external-id',
    #'geo-shape',
    'globe-coordinate',
    #'math',
    #'monolingualtext',
    #'musical-notation',
    'quantity',
    'string',
    #'tabular-data', # maybe in the future but requires formatting the tabular data for the LLM
    'time',
    #'url',
    #'wikibase-form', # lexemes
    'wikibase-item',
    #'wikibase-lexeme',
    #'wikibase-property',
    #'wikibase-sense' # lexemes. could be useful in future work but need to verbalize lexemes too   
])

# %%
filtered_props = [p for p in props if p['datatype'] in datatypes_to_keep]
len(filtered_props)
# Out:
# 2743

# %%
types = set([t for p in props for t in p['types']])

# %%
types_to_keep = set([
 'Wikidata name property',
 'Wikidata qualifier',
 #'Wikidata sandbox property',
 #'about Wikimedia categories',
 'asymmetric property',
 #'for Commons',
 'for a taxon',
 'for astronomical objects',
 'for items about languages',
 'for items about organizations',
 'for items about people',
 'for items about works',
 'for language',
 'for physical quantities',
 'for places',
 #'for property documentation',
 #'for romanization system',
 'for software',
 #'metaproperty',
 #'multi-source external identifier',
 #'obsolete Wikidata property',
 'orderable Wikidata property',
 'related to chemistry',
 'related to economics',
 'related to medicine',
 'related to sport',
 #'representing a unique identifier',
 'symmetric property',
 #'to indicate a constraint',
 'to indicate a location',
 'to indicate a source',
 'transitive property',
 'with datatype string that is not an external identifier'
    # we also keep properties with no types
])

# %%
types_to_remove = types - types_to_keep

# %%
filtered_props = [p for p in filtered_props if len(set(p['types']).intersection(types_to_remove)) == 0]
len(filtered_props)
# Out:
# 2553

# %%
filtered_props_ids = [p['id'] for p in filtered_props]

# %%
with open('filtered_props.pickle', 'wb') as fd:
    pickle.dump(filtered_props, fd)

# %%
filtered_props_dict = {p['id']:p for p in filtered_props}

# %%
with open('/workspace/data/filtered_props_dict.pickle', 'wb') as fd:
    pickle.dump(filtered_props_dict, fd)

# %% [markdown]
# ## Debug

# %%
sub = [p for p in filtered_props if len(p['types']) == 0]
print(len(sub))
sub[:120]
# Out:
# 1187
# [{'datatype': 'string',
#   'id': 'P5471',
#   'label': '2022 Harmonized System Code',
#   'description': 'code in the Harmonized System for a category of object traded internationally',
#   'aliases': ['HSC', 'Harmonised System Code'],
#   'example': [44, 174320, 1578],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P2179',
#   'label': 'ACM Classification Code (2012)',
#   'description': 'ACM Computing Classification Code of 2012 (8 digits)',
#   'aliases': [],
#   'example': [207434, 11463, 42515],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P2540',
#   'label': 'Aarne–Thompson–Uther Tale Type Index',
#   'description': 'index used to classify folktales',
#   'aliases': ['ATU index'],
#   'example': [11841, 2439238],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P799',
#   'label': 'Air Ministry specification ID',
#   'description': 'identifier for an aircraft specification issued by the United Kingdom Air Ministry',
#   'aliases': ['specification', 'UK Air Ministry specification'],
#   'example': [791096, 4133941],
#   'types': []},
#  {'datatype': 'quantity',
#   'id': 'P1661',
#   'label': 'Alexa rank',
#   'description': 'the website\'s Alexa ranking with "point in time" (P585) as a qualifier for each value',
#   'aliases': [],
#   'example': [373, 2013],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P9897',
#   'label': 'App Store age rating',
#   'description': 'content rating category by Apple for software published at the App Store',
#   'aliases': ['app store age', 'age rating', 'app rating'],
#   'example': [19562069, 116947, 106892238],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P2411',
#   'label': 'Artsy gene',
#   'description': 'generalization of artwork type, technique, material, genre, movement, etc. from artsy.net',
#   'aliases': ['artsy.net gene'],
#   'example': [42934, 18761202, 50030],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P3156',
#   'label': 'Australian Classification',
#   'description': 'content rating of an audiovisual work or video game in the Australian Classification system',
#   'aliases': ['ACB', 'ACB rating'],
#   'example': [28234671, 17452],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P9086',
#   'label': 'BAMID film rating',
#   'description': 'rating in the Taiwanese movie content rating system',
#   'aliases': [],
#   'example': [273978, 97160015],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P2629',
#   'label': 'BBFC rating',
#   'description': 'British media content rating (add BBFC reference with qualifier "P2676")',
#   'aliases': ['BBFC certificate'],
#   'example': [16635326, 18517638, 131864, 572903, 691672, 171048],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P6452',
#   'label': 'CBFC rating',
#   'description': 'rating in the Indian film rating system',
#   'aliases': ['Indian censor board ID', 'Indian censor board'],
#   'example': [14948561, 1757288, 29169280],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P9028',
#   'label': 'CCC classification',
#   'description': 'Chilean video game content rating as dictated by Decree 51',
#   'aliases': ['CCC clasification',
#    'Chile age rating',
#    'Consejo de Calificación Cinematográfica rating category'],
#   'example': [28451532, 13522696, 59511757],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P853',
#   'label': 'CERO rating',
#   'description': 'Japanese video game rating system',
#   'aliases': ['Computer Entertainment Rating Organization rating'],
#   'example': [11168, 1153708, 214232, 308961, 40166, 374556],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P6657',
#   'label': 'CHVRS Classification',
#   'description': 'Canadian movie classification',
#   'aliases': ['Canadian Home Video Rating System Classification'],
#   'example': [5552455, 62393177, 205028],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P2758',
#   'label': 'CNC film rating (France)',
#   'description': 'category assigned to a film by the Board of Film Classification (CNC) which what audiences may view it in France',
#   'aliases': ['Commission de classification des œuvres cinématographiques film rating',
#    'film classification category (CNC)',
#    'CNC film rating',
#    'CNC movie rating',
#    'CNC rating'],
#   'example': [190050, 165512, 842720],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P3402',
#   'label': 'CNC film rating (Romania)',
#   'description': 'rating of a movie in the Romanian content rating system',
#   'aliases': ['CNC film rating', 'CNC movie rating', 'CNC rating'],
#   'example': [23762934, 73627, 81037],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P880',
#   'label': 'CPU',
#   'description': 'central processing unit found within the subject item',
#   'aliases': ['central processing unit', 'processor'],
#   'example': [99775, 454390],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P9887',
#   'label': 'Candomblé nation',
#   'description': 'lineage of a terreiro (temple) in Candomblé religion, representing the place of origin or ethnical group of the founders, the dialet used and other liturgy aspects',
#   'aliases': [],
#   'example': [104419272, 104419273],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P5519',
#   'label': 'Cangjie input',
#   'description': 'the Cangjie input code for the character',
#   'aliases': [],
#   'example': [3595029, 3594965, 3594998],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P3880',
#   'label': 'Caverphone',
#   'description': 'phonetic algorithm',
#   'aliases': [],
#   'example': [2803433, 61666959, 2793400],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P3501',
#   'label': 'Christian liturgical rite',
#   'description': 'Christian liturgical rite associated with this item',
#   'aliases': ['Catholic liturgical rite', 'Christian rite', 'Catholic rite'],
#   'example': [1365378, 472189, 210540, 64900, 1365738],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P3216',
#   'label': 'ClassInd rating',
#   'description': 'rating of an audiovisual work, video game or RPG in the Brazilian Advisory Rating System (ClassInd)',
#   'aliases': ['BARS'],
#   'example': [1054036, 62633255],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P2357',
#   'label': 'Classification of Instructional Programs code',
#   'description': "code representing academic disciplines in the U.S. Department of Education's Classification of Instructional Programs",
#   'aliases': ['Classification of Instructional Programs ID',
#    'CIP code',
#    'CIP ID'],
#   'example': [9161265, 3537694],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P9798',
#   'label': 'Classification of the Functions of Government',
#   'description': 'UN classification to compare government agencies across countries',
#   'aliases': ['COFOG number', 'COFOG ID'],
#   'example': [3267995, 10416979, 1972721],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P3879',
#   'label': 'Cologne phonetics',
#   'description': 'phonetic algorithm which assigns to words a sequence of digits, the phonetic code',
#   'aliases': [],
#   'example': [8157228, 11703653],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P6731',
#   'label': 'Commons quality assessment',
#   'description': 'assessment on Wikimedia Commons of the file: featured picture, valued image, quality images, picture of the day, picture of the year etc. Use on media entities only',
#   'aliases': ['Commons featured picture',
#    'Commons valued image',
#    'Quality assessment',
#    'Commons assessment',
#    'Wikimedia Commons assessment',
#    'assessment on Commons',
#    'assessment on Wikimedia Commons'],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P6586',
#   'label': 'Cook Partisan Voting Index',
#   'description': 'a measurement of how strongly a United States congressional district or state leans toward the Democratic or Republican Party, compared to the nation as a whole',
#   'aliases': [],
#   'example': [9553880, 7902303, 6868116],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P5778',
#   'label': 'Cooperative Patent Classification code',
#   'description': 'patent classification code used between the European Patent Office and United States Patent and Trademark Office',
#   'aliases': ['CPC code'],
#   'example': [1139975, 19793, 221262, 47481343, 1402123],
#   'types': []},
#  {'datatype': 'quantity',
#   'id': 'P10273',
#   'label': 'Corruption Perceptions Index',
#   'description': 'Corruption Perceptions Index by Country',
#   'aliases': [],
#   'example': [16951930, 17050037],
#   'types': []},
#  {'datatype': 'quantity',
#   'id': 'P10300',
#   'label': 'DPI for original size',
#   'description': 'resolution in dots per inch (dpi) when printed at original size of painting or other work, value based on pixels of image and size of work (height, width)',
#   'aliases': [],
#   'types': []},
#  {'datatype': 'quantity',
#   'id': 'P8328',
#   'label': 'Democracy Index',
#   'description': 'Democracy Index rating of a country',
#   'aliases': [],
#   'example': [30, 20],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P8359',
#   'label': 'Dewey Decimal Classification (works and editions)',
#   'description': 'DDC number assigned to a publication',
#   'aliases': [],
#   'example': [19128645, 19851135, 19983442, 20592194],
#   'types': []},
#  {'datatype': 'quantity',
#   'id': 'P4105',
#   'label': 'EGF rating',
#   'description': 'rating given by EGF (European Go Federation) to European go players',
#   'aliases': [],
#   'example': [3038855],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P2756',
#   'label': 'EIRIN film rating',
#   'description': 'category in the Japanese film rating system (add EIRIN number with qualifier P2676)',
#   'aliases': ['EIRIN film rating category'],
#   'example': [11361965, 20058691],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P8901',
#   'label': 'ELSPA rating',
#   'description': 'rating of a video game in the British ELSPA rating system (1994 - Spring 2003)',
#   'aliases': [],
#   'example': [2714180, 1931479, 2558736, 209045],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P852',
#   'label': 'ESRB rating',
#   'description': 'North American video game content rating',
#   'aliases': ['Entertainment Software Rating Board rating', 'ESRB'],
#   'example': [11168, 83265, 1150928, 843131, 18325072, 2842078],
#   'types': []},
#  {'datatype': 'quantity',
#   'id': 'P1087',
#   'label': 'Elo rating',
#   'description': "quantitative measure of one's game-playing ability, particularly in classical chess",
#   'aliases': [],
#   'example': [106807, 183250],
#   'types': []},
#  {'datatype': 'quantity',
#   'id': 'P12417',
#   'label': 'Environmental Performance Index',
#   'description': 'value of the EPI index for this country',
#   'aliases': ['EPI'],
#   'example': [17, 35, 869],
#   'types': []},
#  {'datatype': 'quantity',
#   'id': 'P6438',
#   'label': 'Euler characteristic',
#   'description': 'topological invariant of a space; the alternating sum of the dimensions of the (co)homology of a space',
#   'aliases': [],
#   'example': [12507, 1234054, 12510, 633815],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P240',
#   'label': 'FAA airport code',
#   'description': 'three-letter or four-letter alphanumeric code identifying United States airports',
#   'aliases': ['FAA LID'],
#   'example': [2750047, 8685, 286727],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P2371',
#   'label': 'FAO risk status',
#   'description': 'UN Food and Agriculture Organization designation of status for a domesticated breed',
#   'aliases': ['FAO status'],
#   'example': [322890, 33380, 3087896, 5045529, 1953596, 2030755],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P3441',
#   'label': 'FIFA country code',
#   'description': 'three-letter country code assigned by FIFA',
#   'aliases': [],
#   'example': [473248, 188791],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P4437',
#   'label': 'FPB rating',
#   'description': 'rating of a film or video game in the South African media content rating system',
#   'aliases': [],
#   'example': [28056410, 104750296, 107258216],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P1981',
#   'label': 'FSK film rating',
#   'description': 'permitted audience of a film, according to the German film-rating system (add Prüfnummer with qualifier "P2676")',
#   'aliases': [],
#   'example': [72962, 784514],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P2747',
#   'label': 'Filmiroda rating',
#   'description': 'rating of a film in the former (2004–2011) Hungarian film rating system',
#   'aliases': [],
#   'example': [681962, 71978, 72450],
#   'types': []},
#  {'datatype': 'quantity',
#   'id': 'P6697',
#   'label': 'Football Money League rank',
#   'description': 'rank in the Deloitte Football Money League',
#   'aliases': ['Deloitte Football Rank'],
#   'example': [1386924, 1543, 3347591, 18741],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P5070',
#   'label': 'French standard size for oil paintings',
#   'description': 'standard for sizes of canvases for use by artists',
#   'aliases': [],
#   'example': [634122],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P2560',
#   'label': 'GPU',
#   'description': 'graphics processing unit within a system',
#   'aliases': ['graphics processing unit'],
#   'example': [48263],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P9866',
#   'label': 'GRAC rating',
#   'description': 'age rating category as designated by the South Korean Game Rating and Administration Committee (GRAC)',
#   'aliases': ['GRAC'],
#   'example': [26698531, 96217480, 17452],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P3067',
#   'label': 'GS1 country code',
#   'description': 'GS1 Prefix, the first three digits, usually identifying the national GS1 Member Organization to which the manufacturer is registered (not necessarily where the product is actually made)',
#   'aliases': ['Unique Country Code prefix', 'UCC'],
#   'example': [224, 232, 38, 14773],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P916',
#   'label': 'GSRR rating',
#   'description': 'Taiwanese video game content rating system',
#   'aliases': ['CSRR rating', 'GSRMR rating'],
#   'example': [131007, 13455638],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P9325',
#   'label': 'Gedong Kirtya Classification',
#   'description': 'classification of Balinese palm-leaf manuscript based by Nyoman Kadjeng',
#   'aliases': [],
#   'example': [99406302, 99414108, 104521885, 49335, 104529414],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P6608',
#   'label': 'General Material Designation',
#   'description': 'Canadian archival term indicating the broad class of material to which the item belongs',
#   'aliases': [],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P2597',
#   'label': 'Gram staining',
#   'description': 'Gram stain type of a bacterial strain',
#   'aliases': [],
#   'example': [21079489],
#   'types': []},
#  {'datatype': 'time',
#   'id': 'P7295',
#   'label': 'Gregorian calendar start date',
#   'description': 'date the Gregorian calendar was first used',
#   'aliases': ['adoption of the Gregorian calendar',
#    'Gregorian calendar first used',
#    'first date (N.S.)'],
#   'example': [35, 34, 170174],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P5425',
#   'label': 'Han character in this lexeme',
#   'description': 'Han character(s) this lexeme consists of',
#   'aliases': ['Chinese character in this lexeme',
#    'hanzi in this lexeme',
#    'kanji in this lexeme',
#    'hanja in this lexeme',
#    'contain Han character',
#    'contains Han character',
#    'contain Hanzi',
#    'contains Hanzi',
#    'contain kanji',
#    'contains kanji',
#    'contain hanja',
#    'contains hanja',
#    'contain Chinese character',
#    'contains Chinese character',
#    'chữ Hán in this lexeme'],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P5537',
#   'label': 'Hangul pronunciation',
#   'description': 'modern Korean pronunciation(s) in Hangul for this Hanja character',
#   'aliases': [],
#   'example': [3595029, 3594965, 3594998],
#   'types': []},
#  {'datatype': 'quantity',
#   'id': 'P11547',
#   'label': 'Happy Planet Index score',
#   'description': 'The Happy Planet Index (HPI) is an index of human well-being and environmental impact that was introduced by the New Economics Foundation in 2006',
#   'aliases': ['Happy Planet Index'],
#   'example': [155],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P8874',
#   'label': 'Hong Kong film rating',
#   'description': 'Hong Kong film classification system',
#   'aliases': ['OFNAA film rating'],
#   'example': [15293047, 63985561],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P1762',
#   'label': 'Hornbostel-Sachs classification',
#   'description': 'Hornbostel-Sachs classification of a musical instrument',
#   'aliases': ['Sachs–Hornbostel', 'Hornbostel-Sachs'],
#   'example': [659216, 3152896, 8338, 187780, 183932, 5994, 5521203],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P229',
#   'label': 'IATA airline designator',
#   'description': 'two-character identifier for an airline',
#   'aliases': ['IATA reservation code',
#    'International Air Transport Association airline designator'],
#   'example': [308952, 4548, 685605],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P238',
#   'label': 'IATA airport code',
#   'description': 'three-letter identifier for designating airports, railway stations or cities (for airlines, see P229)',
#   'aliases': ['International Air Transport Association airport code',
#    'uio',
#    'IATA station code',
#    'IATA location identifier'],
#   'example': [635361, 3912794, 90],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P3306',
#   'label': 'ICAA rating',
#   'description': 'rating in the Spanish motion picture content rating system',
#   'aliases': [],
#   'example': [20026867, 1170292, 1235281],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P230',
#   'label': 'ICAO airline designator',
#   'description': 'three letter identifier for an airline (two letters only until 1982) (for airports, see P239)',
#   'aliases': ['International Civil Aviation Organization airline designator'],
#   'example': [213147, 4548, 685605],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P239',
#   'label': 'ICAO airport code',
#   'description': 'four-character alphanumeric identifier for designating airports (for airlines, see P230)',
#   'aliases': ['International Civil Aviation Organization airport code',
#    'ICAO aerodrome code',
#    'ICAO airfield code'],
#   'example': [17431, 45523, 3912794],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P4628',
#   'label': 'ICTV virus genome composition',
#   'description': 'classification of viruses of the International Committee on Taxonomy of Viruses by the molecular composition of the virus genome (DNA, RNA, double or single stranded and translational polarity)',
#   'aliases': ['virus group'],
#   'example': [29002462, 6844],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P7573',
#   'label': 'IFCO rating',
#   'description': 'rating certificate of a film in the Irish content classification system',
#   'aliases': [],
#   'example': [20992500, 470560, 6074, 691672],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P5150',
#   'label': 'IGAC rating',
#   'description': 'rating of a film or theatrical production in the Portuguese classification system',
#   'aliases': [],
#   'example': [14616749, 106959150, 111285645],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P10113',
#   'label': 'IMA Mineral Symbol',
#   'description': 'IMA approved symbols (abbreviations) for mineral names',
#   'aliases': [],
#   'example': [104692, 37559],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P579',
#   'label': 'IMA status and/or rank',
#   'description': 'status given to each mineral by the IMA (International Mineralogical Association)',
#   'aliases': [],
#   'example': [318777, 43010],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P5201',
#   'label': 'IMDA rating',
#   'description': 'rating in the Singaporean film and video game rating system',
#   'aliases': ['IMDA classification'],
#   'example': [28532725, 6074],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P3428',
#   'label': 'INCAA film rating',
#   'description': 'rating of a movie in the Argentinian content rating system',
#   'aliases': ['CAEC film rating'],
#   'example': [748851, 72090, 182218],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P4225',
#   'label': 'IPA Braille',
#   'description': 'representation of a IPA phoneme in the Braille system',
#   'aliases': [],
#   'example': [334695, 334723],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P3761',
#   'label': 'IPv4 routing prefix',
#   'description': 'range of IPv4 addresses',
#   'aliases': ['IPv4 range',
#    'IPv4 CIDR',
#    'CIDR',
#    'routing prefix',
#    'IPv4 subnetwork',
#    'subnetwork'],
#   'example': [34433, 246315],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P13150',
#   'label': 'ISCC',
#   'description': 'ISCC hash code that identifies a media object based on fuzzy hashing',
#   'aliases': ['International Standard Content Code'],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P12446',
#   'label': 'ISCED field',
#   'description': 'mapping of a particular course or curriculum to the International Standard Classification of Education (ISCED)',
#   'aliases': [],
#   'example': [113556827, 117599784, 115727347],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P8283',
#   'label': 'ISCO-08 occupation class',
#   'description': 'International Standard Classification of Occupations code according to the International Labour Organization (ILO) classification structure as of 2008',
#   'aliases': ['ISCO-08 occupation code'],
#   'example': [214917, 328325, 1124183],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P952',
#   'label': 'ISCO-88 occupation class',
#   'description': 'International Standard Classification of Occupations code according to the International Labour Organization (ILO) classification structure as of 1988',
#   'aliases': ['CITP',
#    'International Standard Classification of Occupations',
#    'ISCO-88 occupation code'],
#   'example': [214917, 328325, 1124183],
#   'types': []},
#  {'datatype': 'quantity',
#   'id': 'P6789',
#   'label': 'ISO speed',
#   'description': 'light sensitivity of film or digital sensor (e.g. ISO/ASA 100)',
#   'aliases': ['ISO speed rating', 'ASA speed', 'ISO/ASA'],
#   'example': [34788400, 64518538],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P5046',
#   'label': 'International Classification for Standards',
#   'description': 'classification system for technical standards',
#   'aliases': ['ICS', 'ICS ID'],
#   'example': [50101, 1484877, 258311],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P12574',
#   'label': 'International Classification of Nonprofit Organizations',
#   'description': 'industry classification for nonprofit organization created by the Johns Hopkins University and adapted by the United Nations',
#   'aliases': ['ICNPO'],
#   'example': [124022875, 11857638],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P2127',
#   'label': 'International Nuclear Event Scale',
#   'description': 'international scale for rating nuclear events and accidents',
#   'aliases': ['INES'],
#   'example': [486, 840847, 3149899],
#   'types': []},
#  {'datatype': 'quantity',
#   'id': 'P5900',
#   'label': 'JMA Magnitude',
#   'description': 'magnitude of an earthquake according to Japan Meteorological Agency',
#   'aliases': [],
#   'example': [36204, 55080471, 23825118],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P5386',
#   'label': 'JMA Seismic Intensity Scale',
#   'description': 'maximum intensity scale of this earthquake given by JMA Seismic Intensity Scale',
#   'aliases': [],
#   'example': [36204, 55080471, 3742341, 11529237],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P3650',
#   'label': 'JMK film rating',
#   'description': 'rating of a film in the Austrian film rating system',
#   'aliases': [],
#   'example': [637820, 246283],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P5152',
#   'label': 'KAVI rating',
#   'description': 'rating in the Finnish film and television rating system',
#   'aliases': [],
#   'example': [16933688, 38187866, 39070473],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P10994',
#   'label': 'KFCB classification (Kenya)',
#   'description': 'rating in the film classification system of Kenya',
#   'aliases': [],
#   'example': [25999873, 63923947, 105614969, 14566553],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P3818',
#   'label': 'KMRB film rating',
#   'description': 'rating of a film in the South Korean film/video rating system',
#   'aliases': [],
#   'example': [20444585, 61448040],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P2684',
#   'label': 'Kijkwijzer rating',
#   'description': 'Dutch media content rating system',
#   'aliases': [],
#   'example': [16467423, 40895, 146141],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P8360',
#   'label': 'Library of Congress Classification (works and editions)',
#   'description': 'Library of Congress Classification number assigned to a publication; includes both the subject portion and the shelflisting portion of a number',
#   'aliases': ['LCC (works and editions)',
#    'LC Classification (works and editions)',
#    'LC Class Number (works and editions)',
#    'Library of Congress Class Number (works and editions)',
#    'LC Classification and Shelflisting Number'],
#   'example': [17156005, 17416765, 18011319],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P1987',
#   'label': 'MCN code',
#   'description': 'code for item in the Mercosur Common Nomenclature',
#   'aliases': ['Mercosur code'],
#   'example': [164327, 9394, 11426],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P1657',
#   'label': 'MPA film rating',
#   'description': 'US film classification administered by the Motion Picture Association',
#   'aliases': ['Motion Picture Association of America film rating',
#    'MPAA film rating',
#    'Motion Picture Association film rating'],
#   'example': [17738, 190525, 572903],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P8889',
#   'label': 'MTRCB rating',
#   'description': 'rating of a film or television program in the Philippines',
#   'aliases': [],
#   'example': [63985561, 65061643],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P7126',
#   'label': 'Mac OS type code',
#   'description': 'code used formerly by Mac OS to identify file types and programs',
#   'aliases': [],
#   'example': [2141903, 260180, 83570],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P2377',
#   'label': 'MediaWiki hooks used',
#   'description': 'MediaWiki hooks used by this extension',
#   'aliases': [],
#   'example': [27887618],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P5970',
#   'label': 'Medierådet rating',
#   'description': 'rating of a film in the Danish movie content rating system',
#   'aliases': ['Medieradet'],
#   'example': [23006268, 39060366, 28811584, 187266],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P4573',
#   'label': 'Merchant Category Code',
#   'description': 'four-digit number used to classify businesses by the type of goods or services they provide',
#   'aliases': ['MCC'],
#   'example': [32396, 205495, 188920],
#   'types': []},
#  {'datatype': 'quantity',
#   'id': 'P1088',
#   'label': "Mohs' hardness",
#   'description': 'qualitative ordinal scale characterizing scratch resistance of various minerals',
#   'aliases': ['hardness',
#    'Mohs hardness',
#    'mineral hardness',
#    'hardness of mineral'],
#   'example': [43010, 5283, 134583],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P1360',
#   'label': 'Monte Carlo Particle Number',
#   'description': 'number given to each elementary particle',
#   'aliases': ['PDGID', 'PDG ID'],
#   'example': [3198, 2225, 3229],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P10564',
#   'label': 'NAF code v2',
#   'description': 'standard French code for industry classification version 2',
#   'aliases': [],
#   'example': [112165207, 112165493, 112166092, 112166072],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P1931',
#   'label': 'NIOSH Pocket Guide ID',
#   'description': 'Identifier for a chemical in the NIOSH Pocket Guide to Chemical Hazards',
#   'aliases': ['PGCH ID', 'NPG ID'],
#   'example': [49546, 80260, 79583],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P2363',
#   'label': 'NMHH film rating',
#   'description': 'rating of a film in the Hungarian film rating system',
#   'aliases': ['NMHH movie rating'],
#   'example': [14488725, 19679322, 19703943],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P8652',
#   'label': 'Netflix maturity rating',
#   'description': 'content rating used and determined by Netflix in countries where local ratings do not apply to streaming media',
#   'aliases': [],
#   'example': [24905980, 27959455],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P713',
#   'label': "Nickel-Strunz '10th ed', review of (9th ed/ 2009 update)",
#   'description': 'mineral classification Nickel-Strunz version 10 (MinDat)',
#   'aliases': ['Nickel-Strunz 10th ed (pending)'],
#   'example': [5283, 5309],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P712',
#   'label': 'Nickel-Strunz 9th edition (updated 2009)',
#   'description': "mineral classification Nickel-Strunz version 9 (updated 2009, deprecated), a PDF format file. Superseeded by  Nickel-Strunz '10th ed'",
#   'aliases': [],
#   'example': [5283, 182264, 425450],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P11611',
#   'label': 'Norwegian media rating',
#   'description': 'age rating system for motion pictures, video and TV content used in Norway',
#   'aliases': [],
#   'example': [23006268, 39060366, 28811584],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P7327',
#   'label': 'OFLC classification',
#   'description': 'rating in the media content rating system of New Zealand',
#   'aliases': [],
#   'example': [322206, 17036671, 27438121],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P5805',
#   'label': 'OSI Model layer location',
#   'description': 'location of a network protocol in one of the OSI Model layers',
#   'aliases': ['ISO/OSI Model layer location', 'OSI layer', 'OSI Model layer'],
#   'example': [8795, 522, 8777],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P8615',
#   'label': 'Oakeshott typology',
#   'description': 'catalogue of medieval swords',
#   'aliases': [],
#   'example': [678917, 1631165, 463230],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P8480',
#   'label': 'Ofsted inspection rating',
#   'description': 'grade for a school inspection by Ofsted',
#   'aliases': [],
#   'example': [19874262, 3134080, 7545452, 18357690],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P1282',
#   'label': 'OpenStreetMap tag or key',
#   'description': 'OpenStreetMap tagging schema (a Key:key, Tag:key=value, Relation:type, or Role:role) for classes, properties, and values',
#   'aliases': ['OSM tag',
#    'OSM key',
#    'key',
#    'tag',
#    'OpenStreetMap tag',
#    'OpenStreetMap key',
#    'OSM wiki tag or key',
#    'OSM tag or key',
#    '!wosm',
#    'OpenStreetMap relation type',
#    'OSM relation type',
#    'OpenStreetMap relation role',
#    'OSM relation role'],
#   'example': [39715, 9259, 215657],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P908',
#   'label': 'PEGI rating',
#   'description': 'European video game content rating system',
#   'aliases': ['Pan European Game Information rating'],
#   'example': [16681843, 1068669, 15297043, 30138107],
#   'types': []},
#  {'datatype': 'quantity',
#   'id': 'P5593',
#   'label': "Poisson's ratio",
#   'description': 'the negative of the ratio of (signed) transverse strain to (signed) axial strain',
#   'aliases': [],
#   'example': [753, 62246],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P5286',
#   'label': 'Portable Game Notation',
#   'description': 'move of a chess game provided as a string in Portable Game Notation',
#   'aliases': ['PGN'],
#   'example': [723704, 110693],
#   'types': []},
#  {'datatype': 'quantity',
#   'id': 'P4826',
#   'label': 'Program Component Score',
#   'description': 'for figure skating scores breakdown',
#   'aliases': ['PCS', 'Factored Program Components'],
#   'example': [47494432],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P9683',
#   'label': 'Qualis rank',
#   'description': 'rank of an academic journal on the Qualis/CAPES system',
#   'aliases': ['Qualis ranking'],
#   'example': [180445,
#    15753405,
#    15753196,
#    15752815,
#    96704995,
#    4170994,
#    15763470],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P2637',
#   'label': 'RARS rating',
#   'description': 'rating in the Russian media content rating system',
#   'aliases': ['RSVR rating'],
#   'example': [6074, 69523972, 70103903],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P6658',
#   'label': 'RCQ classification',
#   'description': 'movie classification for the Régie du Cinéma Québécois',
#   'aliases': ['RCQ', 'Régie du Cinéma Québécois'],
#   'example': [62393177, 873346, 205028, 6383668],
#   'types': []},
#  {'datatype': 'string',
#   'id': 'P4867',
#   'label': 'RFE symbol',
#   'description': 'symbol of the phonetic alphabet of the Revista de Filología Española corresponding to an AFI phoneme',
#   'aliases': [],
#   'example': [463495, 242797],
#   'types': []},
#  {'datatype': 'wikibase-item',
#   'id': 'P3834',
#   'label': 'RTC film rating',
#   'description': 'rating of a film in the Mexican film classification system',
#   'aliases': [],
#   'example': [24053263, 126796, 132863],
#   'types': []}]
